# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvjeet692/IPL-T20-Data-Analysis/blob/main/IPL_T20_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv('/content/IPL_Data.csv')
T20=pd.read_csv('/content/T20_Data.csv')

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
ipl.columns
# Out:
# Index(['Name', 'Team', 'Url', 'Type', 'ValueinCR', 'Full Name', 'Born', 'Age',
#        'National Side', 'Batting Style', 'Bowling', 'Sport', 'MatchPlayed',
#        'InningsBatted', 'NotOuts', 'RunsScored', 'HighestInnScore', '100s',
#        '50s', '4s', '6s', 'BattingAVG', 'BattingS/R', 'CatchesTaken',
#        'StumpingsMade', 'Ducks', 'R/O', 'InningsBowled', 'Overs', 'Maidens',
#        'RunsConceded', 'Wickets', 'Best', '3s', '5s', 'BowlingAVG',
#        'EconomyRate', 'S/R', 'Mtc'],
#       dtype='object')

# %%
T20.columns
# Out:
# Index(['Name', 'Team', 'Url', 'Type', 'ValueinCR', 'Full Name', 'Born', 'Age',
#        'National Side', 'Batting Style', 'Bowling', 'Sport', 'MatchPlayed',
#        'InningsBatted', 'NotOuts', 'RunsScored', 'HighestInnScore', '100s',
#        '50s', '4s', '6s', 'BattingAVG', 'BattingS/R', 'CatchesTaken',
#        'StumpingsMade', 'Ducks', 'R/O', 'InningsBowled', 'Overs', 'Maidens',
#        'RunsConceded', 'Wickets', 'Best', '3s', '5s', 'BowlingAVG',
#        'EconomyRate', 'S/R', 'Mtc'],
#       dtype='object')

# %% [markdown]
# # 1.List out the batsman who made more 6’s

# %%
six=pd.concat([ipl,T20],ignore_index=True)
six
#six.dropna(subset=['Name'])
# Out:
#                      Name  Team  \
# 0          Mayank Agarwal  PBKS
# 1        Liam Livingstone  PBKS
# 2           Kagiso Rabada  PBKS
# 3           Shahrukh Khan  PBKS
# 4          Shikhar Dhawan  PBKS
# ..                    ...   ...
# 469  Gurkeerat Singh Mann    GT
# 470            Noor Ahmad    GT
# 471      Darshan Nalkande    GT
# 472         Sai Sudharsan    GT
# 473       Pradeep Sangwan    GT
#
#                                                    Url          Type  \
# 0    https://sports.ndtv.com/cricket/players/1430-m...      Batsman
# 1    https://sports.ndtv.com/cricket/players/64363-...  All-Rounder
# 2    https://sports.ndtv.com/cricket/players/64042-...       Bowler
# 3    https://sports.ndtv.com/cricket/players/113433...  All-Rounder
# 4    https://sports.ndtv.com/cricket/players/737-sh...      Batsman
# ..                                                 ...           ...
# 469  https://sports.ndtv.com/cricket/players/1661-g...  All-Rounder
# ...

# %%
six.groupby('Name')['6s'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Rohit Sharma      382.0
# Kieron Pollard    313.0
# Virat Kohli       302.0
# David Warner      300.0
# MS Dhoni          271.0
# Glenn Maxwell     209.0
# KL Rahul          207.0
# Andre Russell     205.0
# Jos Buttler       180.0
# Robin Uthappa     174.0
# Name: 6s, dtype: float64

# %% [markdown]
# # 2.List the batsman who made more **100’s**

# %%
hundreds=pd.concat([ipl,T20],ignore_index='True')
hundreds.dropna(subset=['100s'],inplace=True)
hundreds
# Out:
#                  Name  Team  \
# 0      Mayank Agarwal  PBKS
# 1    Liam Livingstone  PBKS
# 2       Kagiso Rabada  PBKS
# 3       Shahrukh Khan  PBKS
# 4      Shikhar Dhawan  PBKS
# ..                ...   ...
# 462      Matthew Wade    GT
# 463         Jason Roy    GT
# 466     Vijay Shankar    GT
# 467    Dominic Drakes    GT
# 472     Sai Sudharsan    GT
#
#                                                    Url            Type  \
# 0    https://sports.ndtv.com/cricket/players/1430-m...        Batsman
# 1    https://sports.ndtv.com/cricket/players/64363-...    All-Rounder
# 2    https://sports.ndtv.com/cricket/players/64042-...         Bowler
# 3    https://sports.ndtv.com/cricket/players/113433...    All-Rounder
# 4    https://sports.ndtv.com/cricket/players/737-sh...        Batsman
# ..                                                 ...             ...
# 462  https://sports.ndtv.com/cricket/players/1010-m...  Wicket-Keeper
# ...

# %%
#ipl.groupby('Name')['100s'].sum().sort_values(ascending=False).head(15)
#T20.groupby('Name')['100s'].sum().sort_values(ascending=False).head(15)
# Just checking the consistency of the data produced
# Out:
# Name
# Rohit Sharma          4.0
# Glenn Maxwell         3.0
# Mayank Agarwal        3.0
# KL Rahul              2.0
# Glenn Phillips        1.0
# David Warner          1.0
# Krishnappa Gowtham    1.0
# David Miller          1.0
# Jos Buttler           1.0
# Karun Nair            1.0
# Alex Hales            1.0
# Narayan Jagadeesan    1.0
# Rovman Powell         1.0
# Liam Livingstone      1.0
# Faf du Plessis        1.0
# Name: 100s, dtype: float64

# %%
hundreds.groupby('Name')['100s'].sum().sort_values(ascending=False).head(5)
# Out:
# Name
# David Warner      5.0
# Rohit Sharma      5.0
# Virat Kohli       5.0
# Mayank Agarwal    4.0
# KL Rahul          4.0
# Name: 100s, dtype: float64

# %% [markdown]
# # 3.List batsman based on their score

# %%
score=pd.concat([ipl,T20],ignore_index='True')
score.dropna(subset=['RunsScored'])
# Out:
#                  Name  Team  \
# 0      Mayank Agarwal  PBKS
# 1    Liam Livingstone  PBKS
# 2       Kagiso Rabada  PBKS
# 3       Shahrukh Khan  PBKS
# 4      Shikhar Dhawan  PBKS
# ..                ...   ...
# 462      Matthew Wade    GT
# 463         Jason Roy    GT
# 466     Vijay Shankar    GT
# 467    Dominic Drakes    GT
# 472     Sai Sudharsan    GT
#
#                                                    Url            Type  \
# 0    https://sports.ndtv.com/cricket/players/1430-m...        Batsman
# 1    https://sports.ndtv.com/cricket/players/64363-...    All-Rounder
# 2    https://sports.ndtv.com/cricket/players/64042-...         Bowler
# 3    https://sports.ndtv.com/cricket/players/113433...    All-Rounder
# 4    https://sports.ndtv.com/cricket/players/737-sh...        Batsman
# ..                                                 ...             ...
# 462  https://sports.ndtv.com/cricket/players/1010-m...  Wicket-Keeper
# ...

# %%
#ipl[['Name','RunsScored']]
#T20[['Name','RunsScored']]
ipl.columns
# Out:
# Index(['Name', 'Team', 'Url', 'Type', 'ValueinCR', 'Full Name', 'Born', 'Age',
#        'National Side', 'Batting Style', 'Bowling', 'Sport', 'MatchPlayed',
#        'InningsBatted', 'NotOuts', 'RunsScored', 'HighestInnScore', '100s',
#        '50s', '4s', '6s', 'BattingAVG', 'BattingS/R', 'CatchesTaken',
#        'StumpingsMade', 'Ducks', 'R/O', 'InningsBowled', 'Overs', 'Maidens',
#        'RunsConceded', 'Wickets', 'Best', '3s', '5s', 'BowlingAVG',
#        'EconomyRate', 'S/R', 'Mtc'],
#       dtype='object')

# %%
score.groupby('Name')['RunsScored'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Virat Kohli       9579.0
# Rohit Sharma      8924.0
# David Warner      8003.0
# Shikhar Dhawan    7543.0
# MS Dhoni          6363.0
# KL Rahul          5104.0
# Robin Uthappa     4971.0
# Kieron Pollard    4837.0
# Faf du Plessis    4463.0
# Dinesh Karthik    4445.0
# Name: RunsScored, dtype: float64

# %% [markdown]
# # 4.List batsman who has scored **worst**

# %%
#score.groupby('Name')['RunsScored'].sum().sort_values(ascending=True).head(10)

# %%
T20[['Name','S/R']]
ipl['Type'].unique()
# Out:
# array(['Batsman ', 'All-Rounder ', 'Bowler ', 'Wicket-Keeper ',
#        'Wicket-keeper '], dtype=object)

# %% [markdown]
# #5. List batsman whose values based on crores

# %%
ipl.dropna(subset=['ValueinCR'])
(ipl['ValueinCR']==T20['ValueinCR']).all()#checking for the consistency of each player in the terms of their values
# Out:
# True

# %%
batsman_value=ipl[ipl['Type']=='Batsman ']
batsman_value[['Name','ValueinCR']].sort_values(by='ValueinCR',ascending=False)
# Out:
#                       Name  ValueinCR
# 94            Rohit Sharma      16.00
# 72             Virat Kohli      15.00
# 25         Kane Williamson      14.00
# 144           Shreyas Iyer      12.25
# 0           Mayank Agarwal      12.00
# 51         Shimron Hetmyer       8.50
# 28          Rahul Tripathi       8.50
# 4           Shikhar Dhawan       8.25
# 218           Shubman Gill       8.00
# 99        Suryakumar Yadav       8.00
# 53        Devdutt Padikkal       7.75
# 172           Prithvi Shaw       7.50
# 77          Faf du Plessis       7.00
# 175           David Warner       6.25
# 124        Ruturaj Gaikwad       6.00
# 201          Manish Pandey       4.60
# 56        Yashasvi Jaiswal       4.00
# 34             Abdul Samad       4.00
# 222           David Miller       3.00
# 101          Dewald Brevis       3.00
# 178          Rovman Powell       2.80
# 37           Aiden Markram       2.60
# 223        Abhinav Manohar       2.60
# 203             Evin Lewis       2.00
# ...

# %% [markdown]
# #6. List the youngest batsman and eldest batsman

# %%
ipl.dropna(subset=['Age'])
T20.dropna(subset=['Age'])
batsman=ipl[ipl['Type']=='Batsman ']
batsman

# %%
batsman=ipl[ipl['Type']=='Batsman ']
eldest_batter=batsman[['Name','Age']].sort_values(by='Age',ascending=False).head(1)
eldest_batter
# Out:
#               Name                         Age
# 77  Faf du Plessis  37 Years, 8 Months, 2 Days

# %%
youngest_batter=batsman[['Name','Age']].sort_values(by='Age',ascending=True).head(1)
youngest_batter
# Out:
#               Name                           Age
# 101  Dewald Brevis  18 Years, 10 Months, 17 Days

# %% [markdown]
# #7.  List out all Indian batsman those are right handed

# %%
ipl.shape
(ipl['Name']==T20['Name']).all()
#checked whether for  both the data sets the  column name is same or not
# Out:
# True

# %%
T20.columns
T20['Batting Style']
# Out:
# 0      Right Handed
# 1      Right Handed
# 2       Left Handed
# 3      Right Handed
# 4       Left Handed
#            ...
# 232    Right Handed
# 233    Right Handed
# 234    Right Handed
# 235     Left Handed
# 236    Right Handed
# Name: Batting Style, Length: 237, dtype: object

# %%
Ind_Rgt_Handed=T20[(T20['National Side']=='India') & (T20['Batting Style']=='Right Handed')]
Ind_Rgt_Handed[['Name','National Side','Batting Style']]
# Out:
#                      Name National Side Batting Style
# 0          Mayank Agarwal         India  Right Handed
# 3           Shahrukh Khan         India  Right Handed
# 7            Rahul Chahar         India  Right Handed
# 10          Vaibhav Arora         India  Right Handed
# 13      Prabhsimran Singh         India  Right Handed
# ..                    ...           ...           ...
# 229         Vijay Shankar         India  Right Handed
# 231           Varun Aaron         India  Right Handed
# 232  Gurkeerat Singh Mann         India  Right Handed
# 234      Darshan Nalkande         India  Right Handed
# 236       Pradeep Sangwan         India  Right Handed
#
# [111 rows x 3 columns]

# %% [markdown]
# #8. List out all England batsman who scored the highest

# %%
df=pd.concat([ipl,T20],ignore_index=True)
df1=df[df['National Side']=='England'].sort_values(by='RunsScored',ascending=False).head(10)
df1.groupby('Name')['RunsScored'].sum().sort_values(ascending=False).head(10)
#df1[['Name','National Side','RunsScored']]
# Out:
# Name
# Jos Buttler       4108.0
# Jonny Bairstow    2228.0
# Alex Hales        1644.0
# Jason Roy         1438.0
# Moeen Ali         1303.0
# Sam Billings       478.0
# Chris Jordan       358.0
# Name: RunsScored, dtype: float64

# %% [markdown]
# #Question2

# %% [markdown]
# # 1.List out the bowler who made more wickets

# %%
ipl[['Name','Wickets']]
ipl.columns
# Out:
# Index(['Name', 'Team', 'Url', 'Type', 'ValueinCR', 'Full Name', 'Born', 'Age',
#        'National Side', 'Batting Style', 'Bowling', 'Sport', 'MatchPlayed',
#        'InningsBatted', 'NotOuts', 'RunsScored', 'HighestInnScore', '100s',
#        '50s', '4s', '6s', 'BattingAVG', 'BattingS/R', 'CatchesTaken',
#        'StumpingsMade', 'Ducks', 'R/O', 'InningsBowled', 'Overs', 'Maidens',
#        'RunsConceded', 'Wickets', 'Best', '3s', '5s', 'BowlingAVG',
#        'EconomyRate', 'S/R', 'Mtc'],
#       dtype='object')

# %%
ipl.dropna(subset=['Wickets'])
T20.dropna(subset=['Wickets'])
bowler_with_more_wickets=pd.concat([ipl,T20],ignore_index=True)
bowler_with_more_wickets.groupby('Name')['Wickets'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Dwayne Bravo           245.0
# Yuzvendra Chahal       207.0
# Ravichandran Ashwin    206.0
# Bhuvneshwar Kumar      200.0
# Rashid Khan            198.0
# Jasprit Bumrah         197.0
# Sunil Narine           195.0
# Ravindra Jadeja        175.0
# Tim Southee            142.0
# Trent Boult            138.0
# Name: Wickets, dtype: float64

# %% [markdown]
# #2. List the player who made more maiden overs

# %%
ipl[['Name','Maidens']]
# Out:
#                      Name  Maidens
# 0          Mayank Agarwal      NaN
# 1        Liam Livingstone      0.0
# 2           Kagiso Rabada      2.0
# 3           Shahrukh Khan      NaN
# 4          Shikhar Dhawan      0.0
# ..                    ...      ...
# 232  Gurkeerat Singh Mann      0.0
# 233            Noor Ahmad      NaN
# 234      Darshan Nalkande      NaN
# 235         Sai Sudharsan      NaN
# 236       Pradeep Sangwan      1.0
#
# [237 rows x 2 columns]

# %%
ipl.dropna(subset=['Maidens'])
T20.dropna(subset=['Maidens'])
# Out:
#                            Name  Team  \
# 0                Mayank Agarwal  PBKS
# 1              Liam Livingstone  PBKS
# 2                 Kagiso Rabada  PBKS
# 3                 Shahrukh Khan  PBKS
# 6                   Odean Smith  PBKS
# ..                          ...   ...
# 219              Mohammed Shami    GT
# 221  Ravisrinivasan Sai Kishore    GT
# 223             Abhinav Manohar    GT
# 229               Vijay Shankar    GT
# 230              Dominic Drakes    GT
#
#                                                    Url          Type  \
# 0    https://sports.ndtv.com/cricket/players/1430-m...      Batsman
# 1    https://sports.ndtv.com/cricket/players/64363-...  All-Rounder
# 2    https://sports.ndtv.com/cricket/players/64042-...       Bowler
# 3    https://sports.ndtv.com/cricket/players/113433...  All-Rounder
# 6    https://sports.ndtv.com/cricket/players/108548...  All-Rounder
# ..                                                 ...           ...
# ...

# %%
Players_with_Maiden=pd.concat([ipl,T20],ignore_index=True)
Players_with_Maiden.groupby('Name')['Maidens'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Jasprit Bumrah                13.0
# Bhuvneshwar Kumar             12.0
# Sandeep Sharma                 8.0
# Deepak Chahar                  7.0
# Mustafizur Rahman              7.0
# Ravisrinivasan Sai Kishore     7.0
# Trent Boult                    6.0
# Ravichandran Ashwin            6.0
# Ravindra Jadeja                6.0
# Yuzvendra Chahal               5.0
# Name: Maidens, dtype: float64

# %% [markdown]
# #3. List bowler based on their number of runs conceded

# %%
ipl.dropna(subset=['RunsConceded'])
T20.dropna(subset=['RunsConceded'])

# %%
Runs_conceded=pd.concat([ipl,T20],ignore_index=True)
Runs_conceded.groupby('Name')['RunsConceded'].sum().sort_values(ascending=False)
# Out:
# Name
# Dwayne Bravo             6097.0
# Ravichandran Ashwin      5329.0
# Ravindra Jadeja          5134.0
# Bhuvneshwar Kumar        5048.0
# Yuzvendra Chahal         4820.0
#                           ...
# Ravikumar Samarth           0.0
# Aryan Juyal                 0.0
# Ashok Sharma                0.0
# Rassie van der Dussen       0.0
# Rahul Tewatia               0.0
# Name: RunsConceded, Length: 237, dtype: float64

# %% [markdown]
# #4. List bowler who has worst bowling average

# %%
ipl.BowlingAVG
T20.BowlingAVG
T20.columns
#ipl[['Name','BowlingAVG']].sort_values(by='BowlingAVG',ascending=False)
ipl[['Name','Type']]
ipl['Type'].unique()
# Out:
# array(['Batsman ', 'All-Rounder ', 'Bowler ', 'Wicket-Keeper ',
#        'Wicket-keeper '], dtype=object)

# %%
ipl.dropna(subset=['BowlingAVG'])
T20.dropna(subset=['BowlingAVG'])

# %%
df_piledup=pd.concat([ipl,T20],ignore_index=True)
bowlers_df=df_piledup[df_piledup['Type']=='Bowler ']
bowlers_df.groupby('Name')['RunsConceded','Wickets','BowlingAVG'].mean().sort_values(by='BowlingAVG',ascending=False).dropna(subset='BowlingAVG')
# Out:
# <ipython-input-57-03e1aedb34c9>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bowlers_df.groupby('Name')['RunsConceded','Wickets','BowlingAVG'].mean().sort_values(by='BowlingAVG',ascending=False).dropna(subset='BowlingAVG')
#                             RunsConceded  Wickets  BowlingAVG
# Name
# Tushar Deshpande                   192.0      3.0      64.000
# Nathan Ellis                        70.0      3.0      50.000
# Sandeep Sharma                    1461.0     56.5      49.215
# Umran Malik                         96.0      2.0      48.000
# Varun Chakravarthy                 485.5     19.0      44.650
# ...                                  ...      ...         ...
# Ravisrinivasan Sai Kishore         960.0     55.0      17.450
# Obed McCoy                         320.0     19.0      16.840
# Rashid Khan                       1634.5     99.0      16.735
# ...

# %% [markdown]
# #5.List bowler whose values based on crores

# %%
#(ipl['ValueinCR']==T20['ValueinCR']).all()#just a usual check
#ipl.dropna(subset=['ValueinCR'])
bowler_value_inCr=ipl[(ipl['Type']=='Bowler ')].sort_values(by='ValueinCR',ascending=False)
bowler_value_inCr[['Name','ValueinCR']]
# Out:
#                    Name  ValueinCR
# 214         Rashid Khan      15.00
# 120       Deepak Chahar      14.00
# 96       Jasprit Bumrah      12.00
# 170      Shardul Thakur      10.75
# 216     Lockie Ferguson      10.00
# ..                  ...        ...
# 165          Rasikh Dar       0.20
# 44        Saurabh Dubey       0.20
# 45   Jagadeesha Suchith       0.20
# 69          Kuldeep Sen       0.20
# 212        Mayank Yadav       0.20
#
# [77 rows x 2 columns]

# %% [markdown]
# #6. List the youngest bowler and eldest bowler

# %%
result=ipl[ipl['Type']=='Bowler ']
result[['Name','Age']].sort_values(by='Age',ascending=False).dropna(subset=['Age']).head(1)
# Out:
#                    Name                         Age
# 59  Nathan Coulter-Nile  34 Years, 5 Months, 5 Days

# %% [markdown]
# # 7.List out all South African Bowler those are off-break

# %%
ipl.columns
(ipl['Bowling']==T20['Bowling']).all()
T20['Bowling']
T20.columns
T20['Type']
# Out:
# 0          Batsman
# 1      All-Rounder
# 2           Bowler
# 3      All-Rounder
# 4          Batsman
#            ...
# 232    All-Rounder
# 233         Bowler
# 234    All-Rounder
# 235    All-Rounder
# 236    All-Rounder
# Name: Type, Length: 237, dtype: object

# %%
SF_OffBreak=T20[(T20['National Side']=='South Africa') & (T20['Type']=='Bowler ') & (T20['Bowling']=='Off break')]
SF_OffBreak[['Name','National Side','Bowling','Type']]
#no such South African bowler is there.
# Out:
# Empty DataFrame
# Columns: [Name, National Side, Bowling, Type]
# Index: []

# %% [markdown]
# ***Assume that you are creating an IPL team say DSPL, how
# do you shuffle the existing team in such a way that the
# total team budget is not exceeding 100 crores and then
# you get 4 batsman, 4 bowlers, 2 all rounder, 1 wicket
# keeper, they could win the final cup***

# %%
ipl.head()
# Out:
#                Name  Team                                                Url  \
# 0    Mayank Agarwal  PBKS  https://sports.ndtv.com/cricket/players/1430-m...
# 1  Liam Livingstone  PBKS  https://sports.ndtv.com/cricket/players/64363-...
# 2     Kagiso Rabada  PBKS  https://sports.ndtv.com/cricket/players/64042-...
# 3     Shahrukh Khan  PBKS  https://sports.ndtv.com/cricket/players/113433...
# 4    Shikhar Dhawan  PBKS  https://sports.ndtv.com/cricket/players/737-sh...
#
#            Type  ValueinCR                 Full Name  \
# 0      Batsman       12.00     Mayank Anurag Agarwal
# 1  All-Rounder       11.50  Liam Stephen Livingstone
# 2       Bowler        9.25             Kagiso Rabada
# 3  All-Rounder        9.00      Masood Shahrukh Khan
# 4      Batsman        8.25            Shikhar Dhawan
#
#                                            Born                          Age  \
# 0        February 16, 1991 Bangalore, Karnataka  31 Years, 0 Months, 28 Days
# ...

# %%
ipl1=ipl[(ipl['Type']=='Batsman ')&(ipl['InningsBatted']>40)]
T20_new=T20[(T20['Type']=='Batsman ')&(T20['InningsBatted']>40)]
T20_new['InningsBatted']
# Out:
# 4       66.0
# 25      72.0
# 72      89.0
# 77      50.0
# 94     117.0
# 155     60.0
# 175     88.0
# 222     83.0
# 226     57.0
# Name: InningsBatted, dtype: float64

# %%
overall=pd.concat([ipl1,T20_new],ignore_index=True)
batter=overall[['Name','InningsBatted', 'BattingAVG', 'BattingS/R','ValueinCR']]
top_batter=pd.DataFrame(batter.groupby('Name')['BattingS/R','ValueinCR','BattingAVG'].mean().sort_values(by=['BattingS/R','ValueinCR'],ascending=False)).head(4)
top_batter
# Out:
# <ipython-input-8-d43031bf2e33>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   top_batter=pd.DataFrame(batter.groupby('Name')['BattingS/R','ValueinCR','BattingAVG'].mean().sort_values(by=['BattingS/R','ValueinCR'],ascending=False)).head(4)
#               BattingS/R  ValueinCR  BattingAVG
# Name
# Prithvi Shaw      146.30       7.50      24.620
# Jason Roy         143.37       2.00      25.670
# David Warner      140.22       6.25      37.165
# David Miller      138.57       3.00      32.395

# %%
ipl2=ipl[(ipl['Type']=='Bowler ')&(ipl['InningsBowled']>50)]
T20_new1=T20[(T20['Type']=='Bowler ')&(T20['InningsBatted']>50)]

# %%
over_all=pd.concat([ipl2,T20_new1],ignore_index=True)
bowler=over_all[['Name','InningsBowled', 'BowlingAVG', 'EconomyRate','ValueinCR']]
top_bowler=pd.DataFrame(bowler.groupby('Name')['InningsBowled', 'BowlingAVG', 'EconomyRate','ValueinCR'].mean().sort_values(by=['EconomyRate','ValueinCR'],ascending=True)).head(4)
top_bowler
# Out:
# <ipython-input-10-ba85f2ddab66>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   top_bowler=pd.DataFrame(bowler.groupby('Name')['InningsBowled', 'BowlingAVG', 'EconomyRate','ValueinCR'].mean().sort_values(by=['EconomyRate','ValueinCR'],ascending=True)).head(4)
#                    InningsBowled  BowlingAVG  EconomyRate  ValueinCR
# Name
# Rashid Khan                 76.0       20.55         6.33       15.0
# Bhuvneshwar Kumar          132.0       25.26         7.30        4.2
# Jasprit Bumrah             106.0       23.05         7.42       12.0
# Shahbaz Nadeem              70.0       37.16         7.56        0.5

# %%
ipl3=ipl[(ipl['Type']=='All-Rounder')&(ipl['MatchPlayed']>40)]
T20_new2=T20[(T20['Type']=='All-Rounder')&(T20['MatchPlayed']>40)]
overall_=pd.concat([ipl3,T20],ignore_index=True)
overall["EconomyRate"].mean()
overall["EconomyRate"].min()
overall1=overall[overall["EconomyRate"]<4]

all_rounder=pd.DataFrame(overall_.groupby('Name')['BattingS/R','ValueinCR'].mean().sort_values(by=['BattingS/R','ValueinCR'],ascending=False)).head(2)
all_rounder
# Out:
# <ipython-input-17-641e53b989fd>:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   all_rounder=pd.DataFrame(overall_.groupby('Name')['BattingS/R','ValueinCR'].mean().sort_values(by=['BattingS/R','ValueinCR'],ascending=False)).head(2)
#                BattingS/R  ValueinCR
# Name
# Deepak Chahar      244.44       14.0
# Finn Allen         190.24        0.8

# %%
ipl1=ipl[(ipl['Type']=='Batsman ')&(ipl['InningsBatted']>40)]
T20_new=T20[(T20['Type']=='Batsman ')&(T20['InningsBatted']>40)]
ipl["Type"].unique()
# Out:
# array(['Batsman ', 'All-Rounder ', 'Bowler ', 'Wicket-Keeper ',
#        'Wicket-keeper '], dtype=object)

# %%
ipl1=ipl[(ipl['Type']=='Wicket-Keeper ')]
ipl1.head(5)
# Out:
#                  Name  Team  \
# 5      Jonny Bairstow  PBKS
# 13  Prabhsimran Singh  PBKS
# 22      Jitesh Sharma  PBKS
# 26    Nicholas Pooran   SRH
# 39     Glenn Phillips   SRH
#
#                                                   Url            Type  \
# 5   https://sports.ndtv.com/cricket/players/1551-j...  Wicket-Keeper
# 13  https://sports.ndtv.com/cricket/players/110976...  Wicket-Keeper
# 22  https://sports.ndtv.com/cricket/players/106754...  Wicket-Keeper
# 26  https://sports.ndtv.com/cricket/players/1720-n...  Wicket-Keeper
# 39  https://sports.ndtv.com/cricket/players/107472...  Wicket-Keeper
#
#     ValueinCR               Full Name  \
# 5        6.75  Jonathan Marc Bairstow
# 13       0.60       Prabhsimran Singh
# 22       0.20     Jitesh Mohan Sharma
# 26      10.75         Nicholas Pooran
# 39       1.50  Glenn Dominic Phillips
#
#                                           Born                          Age  \
# ...
